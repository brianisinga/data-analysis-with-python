# %% [markdown]
# <a href="https://colab.research.google.com/github/brianisinga/data-analysis-with-python/blob/main/Untitled29.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data=pd.read_csv('monkeypox.csv')

# %%
data
# Out:
#       Age  Gender Region  Fever  Headache  Muscle_Pains  Swollen_Lymph_Nodes  \
# 0      25   Other  Urban      1         0             0                    0
# 1      85   Other  Urban      0         0             0                    0
# 2      52  Female  Urban      0         1             1                    1
# 3      70  Female  Rural      0         0             0                    0
# 4      26    Male  Rural      0         0             0                    0
# ...   ...     ...    ...    ...       ...           ...                  ...
# 3495   44  Female  Rural      0         0             0                    0
# 3496   20   Other  Rural      0         1             1                    0
# 3497   17   Other  Urban      0         0             0                    0
# 3498   96   Other  Urban      0         1             0                    0
# 3499   33  Female  Rural      0         0             0                    0
#
# ...
